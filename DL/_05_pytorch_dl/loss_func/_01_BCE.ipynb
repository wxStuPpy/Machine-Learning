# %% [markdown]
# 二分类损失函数

# %%
import torch
import torch.nn as nn

# %%
input=torch.randn(3,2)
print(input)
#得到预测概率值
pred=torch.sigmoid(input)
# Out:
# tensor([[ 0.2090, -0.4281],
#         [ 0.1733, -0.6258],
#         [-0.0332, -0.0730]])

# %%
target=torch.tensor([[0,1],[1,0],[0,1]]).float()
print(target)
# Out:
# tensor([[0., 1.],
#         [1., 0.],
#         [0., 1.]])

# %%
loss=nn.BCELoss()
print(loss(pred,target))
# Out:
# tensor(0.6965)
