# %%
import torch
import torch.nn as nn
from torch.nn.functional import smooth_l1_loss

# %%
input=torch.randn(3,5)
target=torch.randn(3,5)
print(input)
print(target)
# Out:
# tensor([[ 0.2636, -1.1380, -0.1237, -0.5748,  0.2591],
#         [-1.0715, -0.6722,  1.0911,  1.0039, -0.7500],
#         [-1.5667, -0.3204, -0.0657,  1.2289, -1.9719]])
# tensor([[ 0.1742,  0.4193,  0.1189, -1.7829, -0.0172],
#         [-0.2174,  1.1490, -0.9164, -0.0545, -0.1366],
#         [ 1.0777,  0.6219,  0.5123,  0.8542, -1.2145]])

# %%
#MSE:L2 LOSS
mse_loss=nn.MSELoss()
print(mse_loss(input,target))
# Out:
# tensor(1.5020)

# %%
#MAE:L1 LOSS
mse_loss=nn.L1Loss()
print(mse_loss(input,target))
# Out:
# tensor(1.0017)

# %%
#Smooth L1
smooth_l1_loss=nn.SmoothL1Loss()
print(smooth_l1_loss(input,target))
# Out:
# tensor(0.5926)
