# %%
import torch

# %%
#1.四则运算
t1=torch.randint(low=0,high=10,size=(2,3))
t2=torch.randint(low=0,high=10,size=(2,3))
print(t1)
print(t2)
# Out:
# tensor([[1, 0, 7],
#         [0, 8, 4]])
# tensor([[1, 4, 3],
#         [7, 6, 7]])
